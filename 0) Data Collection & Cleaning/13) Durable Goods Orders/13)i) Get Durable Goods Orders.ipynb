# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import pprint as pp
import requests

# %%
# Get Durable Goods 

api_key = 'YOUR_API_KEY'

url = f'https://www.alphavantage.co/query?function=DURABLES&apikey={api_key}'
r = requests.get(url)
data = r.json()

# %%
data.keys()
# Out:
# dict_keys(['name', 'interval', 'unit', 'data'])

# %%
pp.pprint(data)
# Out:
# {'data': [{'date': '2024-08-01', 'value': '289211.0'},
#           {'date': '2024-07-01', 'value': '268942.0'},
#           {'date': '2024-06-01', 'value': '287595.0'},
#           {'date': '2024-05-01', 'value': '284736.0'},
#           {'date': '2024-04-01', 'value': '275566.0'},
#           {'date': '2024-03-01', 'value': '305526.0'},
#           {'date': '2024-02-01', 'value': '268258.0'},
#           {'date': '2024-01-01', 'value': '252522.0'},
#           {'date': '2023-12-01', 'value': '299969.0'},
#           {'date': '2023-11-01', 'value': '286515.0'},
#           {'date': '2023-10-01', 'value': '278895.0'},
#           {'date': '2023-09-01', 'value': '308103.0'},
#           {'date': '2023-08-01', 'value': '290578.0'},
#           {'date': '2023-07-01', 'value': '261612.0'},
#           {'date': '2023-06-01', 'value': '324238.0'},
#           {'date': '2023-05-01', 'value': '288640.0'},
#           {'date': '2023-04-01', 'value': '272375'},
# ...

# %%
monthly_durable_goods_df = pd.DataFrame(data['data'])
monthly_durable_goods_df.head()
# Out:
#          date     value
# 0  2024-08-01  289211.0
# 1  2024-07-01  268942.0
# 2  2024-06-01  287595.0
# 3  2024-05-01  284736.0
# 4  2024-04-01  275566.0

# %%
monthly_durable_goods_df.to_csv(f'monthly_durable_goods.csv', index=False)
