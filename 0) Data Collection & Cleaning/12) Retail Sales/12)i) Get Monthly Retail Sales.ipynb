# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import pprint as pp
import requests

# %%
# Get Retail Sales

api_key = 'YOUR_API_KEY'

url = f'https://www.alphavantage.co/query?function=RETAIL_SALES&apikey={api_key}'
r = requests.get(url)
data = r.json()

# %%
data.keys()
# Out:
# dict_keys(['name', 'interval', 'unit', 'data'])

# %%
pp.pprint(data)
# Out:
# {'data': [{'date': '2024-08-01', 'value': '637747.0'},
#           {'date': '2024-07-01', 'value': '629023.0'},
#           {'date': '2024-06-01', 'value': '604360.0'},
#           {'date': '2024-05-01', 'value': '643843.0'},
#           {'date': '2024-04-01', 'value': '605419.0'},
#           {'date': '2024-03-01', 'value': '609462.0'},
#           {'date': '2024-02-01', 'value': '555528.0'},
#           {'date': '2024-01-01', 'value': '552441.0'},
#           {'date': '2023-12-01', 'value': '668957.0'},
#           {'date': '2023-11-01', 'value': '619189.0'},
#           {'date': '2023-10-01', 'value': '604435.0'},
#           {'date': '2023-09-01', 'value': '589258.0'},
#           {'date': '2023-08-01', 'value': '624457.0'},
#           {'date': '2023-07-01', 'value': '601631.0'},
#           {'date': '2023-06-01', 'value': '608430.0'},
#           {'date': '2023-05-01', 'value': '627266.0'},
#           {'date': '2023-04-01', 'value': '584626.0'},
# ...

# %%
monthly_retail_sales_df = pd.DataFrame(data['data'])
monthly_retail_sales_df.head()
# Out:
#          date     value
# 0  2024-08-01  637747.0
# 1  2024-07-01  629023.0
# 2  2024-06-01  604360.0
# 3  2024-05-01  643843.0
# 4  2024-04-01  605419.0

# %%
monthly_retail_sales_df .to_csv(f'monthly_retail_sales.csv', index=False)
