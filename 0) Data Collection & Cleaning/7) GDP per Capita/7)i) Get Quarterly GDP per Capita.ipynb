# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import pprint as pp
import requests

# %%
# Get GDP - Quarterly & Annual

api_key = 'YOUR_API_KEY'

url = f'https://www.alphavantage.co/query?function=REAL_GDP_PER_CAPITA&apikey={api_key}'
r = requests.get(url)
data = r.json()

# %%
data.keys()
# Out:
# dict_keys(['name', 'interval', 'unit', 'data'])

# %%
pp.pprint(data)
# Out:
# {'data': [{'date': '2024-04-01', 'value': '68977.0'},
#           {'date': '2024-01-01', 'value': '68549.0'},
#           {'date': '2023-10-01', 'value': '68351.0'},
#           {'date': '2023-07-01', 'value': '67916.0'},
#           {'date': '2023-04-01', 'value': '67295.0'},
#           {'date': '2023-01-01', 'value': '66967.0'},
#           {'date': '2022-10-01', 'value': '66575.0'},
#           {'date': '2022-07-01', 'value': '66115.0'},
#           {'date': '2022-04-01', 'value': '65760.0'},
#           {'date': '2022-01-01', 'value': '65779.0'},
#           {'date': '2021-10-01', 'value': '65986.0'},
#           {'date': '2021-07-01', 'value': '64877.0'},
#           {'date': '2021-04-01', 'value': '64392.0'},
#           {'date': '2021-01-01', 'value': '63428.0'},
#           {'date': '2020-10-01', 'value': '62554.0'},
#           {'date': '2020-07-01', 'value': '61915.0'},
#           {'date': '2020-04-01', 'value': '57449.0'},
# ...

# %%
quarterly_gdp_df = pd.DataFrame(data['data'])
quarterly_gdp_df.head()
# Out:
#          date    value
# 0  2024-04-01  68977.0
# 1  2024-01-01  68549.0
# 2  2023-10-01  68351.0
# 3  2023-07-01  67916.0
# 4  2023-04-01  67295.0

# %%
quarterly_gdp_df.to_csv(f'quarterly_GDP_per_Capita.csv', index=False)
